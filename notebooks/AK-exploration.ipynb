# %% [markdown]
# # Exploration

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import set_config; set_config(display='diagram')
from PIL import Image

# %%
Img104648 = Image.open('../raw_data/images_test_rev1/104648.jpg')
Img104648
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=424x424 at 0x11F04CDF0>

# %%
Img104648array = np.array(Img104648)
Img104648array
# Out:
# array([[[ 9,  9,  9],
#         [ 7,  7,  7],
#         [ 4,  4,  4],
#         ...,
#         [ 6,  4,  5],
#         [ 5,  3,  4],
#         [ 4,  2,  3]],
#
#        [[ 7,  7,  7],
#         [ 5,  5,  5],
#         [ 3,  3,  3],
#         ...,
#         [ 7,  5,  6],
#         [ 6,  4,  5],
#         [ 6,  4,  5]],
#
#        [[ 5,  5,  5],
#         [ 4,  4,  4],
#         [ 3,  3,  3],
#         ...,
#         [ 8,  6,  7],
#         [ 7,  5,  6],
#         [ 7,  5,  6]],
#
#        ...,
#
#        [[ 3,  2,  0],
#         [ 6,  5,  1],
#         [ 8,  7,  5],
#         ...,
#         [ 2,  1,  0],
#         [ 3,  2,  0],
#         [ 9,  8,  6]],
#
#        [[13, 12,  8],
#         [17, 16, 12],
#         [19, 18, 16],
#         ...,
#         [ 6,  5,  3],
#         [ 6,  5,  3],
#         [11, 10,  8]],
#
#        [[25, 24, 20],
#         [28, 27, 23],
#         [30, 29, 27],
#         ...,
#         [ 6,  5,  3],
#         [ 4,  3,  1],
#         [ 6,  5,  3]]], dtype=uint8)

# %%
Img104648array.shape
# Out:
# (424, 424, 3)

# %%
Arrayimage = (np.array(Image.open('../raw_data/images_test_rev1/107120.jpg'))).shape
Arrayimage
# Out:
# (424, 424, 3)

# %%
Image
# Out:
# <module 'PIL.Image' from '/Users/kosowski/.pyenv/versions/3.8.6/envs/GalaxyProject/lib/python3.8/site-packages/PIL/Image.py'>

# %%
df = pd.read_csv('../raw_data/central_pixel_benchmark.csv')
df.head()
# Out:
#    GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0    100018  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
# 1    100037  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
# 2    100042  0.408863  0.550817  0.040320  0.085001  0.465816  0.117082
# 3    100052  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 4    100056  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
#
#    Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 0  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
# 1  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
# 2  0.348734  0.225783  0.240033  ...  0.054510   0.068422   0.087200
# 3  0.398573  0.310370  0.209988  ...  0.058241   0.128488   0.123550
# 4  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
#
#    Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  Class11.6
# ...

# %%
df.sort_values('Class1.3')
# Out:
#        GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 61541    792009  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 60934    785028  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 60936    785047  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 22324    350013  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 60938    785084  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# ...         ...       ...       ...       ...       ...       ...       ...
# 57952    750587  0.333361  0.610524  0.056115  0.097821  0.512703  0.129306
# 72460    915535  0.333361  0.610524  0.056115  0.097821  0.512703  0.129306
# 45015    602867  0.333361  0.610524  0.056115  0.097821  0.512703  0.129306
# 64628    826869  0.333361  0.610524  0.056115  0.097821  0.512703  0.129306
# 63777    816909  0.333361  0.610524  0.056115  0.097821  0.512703  0.129306
#
# ...

# %%
Image.open('../data/images_test_rev1/792009.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=424x424 at 0x11A930E80>

# %% [markdown]
# # Final tree

# %%
output = df.iloc[4,:]

# %%
#OUTPUT
#class 1 : what does it look like ?
smooth = output[0]
feature_or_disk = output[1]
star = output[2]

if smooth > 0.5:
    #go to class 7
    elif featureordisk >0.5 :
    #go to class 2  
    else:
    #stop --> output : étoile
# Out:
#   File "<ipython-input-24-60de9a2f64f5>", line 8
#     elif:
#     ^
# SyntaxError: invalid syntax

# %%
#class 2 : featureordisk --> could this be a disk view edge-on ?
featureordisk_yes = output[3] 
featureordisk_no = output[4]

if featureordisk.yes >0.5:
    #go to class 9
    else:
    #go to class 3
# Out:
#   File "<ipython-input-23-b411eece3b72>", line 5
#     if featureordisk.yes >0,5:
#                            ^
# SyntaxError: invalid syntax

# %%
#class 3 : featureordisk --> featureordisk.no --> is there a sign of bar feature ?
barfeature_yes = output[5]
barfeature_no = output[6]

all:
    #go to class 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-86203568795a> in <module>
#       1 #class 3
# ----> 2 barfeature.yes = output[5]
#       3 barfeature.no = output[6]
#
# NameError: name 'barfeature' is not defined

# %%
#class 4 : featureordisk --> no --> barfeature.yes/no --> spiral arm pattern ?
arm_yes = output[7]
arm_no = output[8]

if barfeature.yes >0.5:
    #go to class 10
    else:
    #go to class 5

# %%
#class 5 : prominence of central buldge ?
#featureordisk --> no --> barfeature.yes/no --> arm.no
#featureordisk --> no --> barfeature.yes/no --> arm.yes --> all arms sizes --> all number of arms

no_bulge = output[9]
noticeable_bulge = output[10]
obvious_bulge = output[11]
dominant_bulge = output[12]

all:
    #go to class 6

# %%
#class 6 - is there anything odd ?
#featureordisk --> no --> barfeature.yes/no --> arm.no --> all
#Smooth --> class 7 : all
#featureordisk --> featureordisk.yes --> class 9 :all

odd_yes = output[13]
odd_no = output[14]

if odd.yes >0.5:
    #go to class 8
    else:
        #stop --> what is it then ?

# %%
#OUTPUT
#class 8 : featureordisk --> no --> barfeature.yes/no --> arm.no --> all --> odd.yes --> ring, 
#disturber or irregular ?

ring = output[18]
lens_or_arc = output[19]
disturbed = output[20]
irregular = output[21]
other = output[22]
merger = output[23]
dust_lane = output[24]

all:
    #stop

# %%
#class 9 : featureordisk --> featureordisk.yes --> if there a bulge, if yes what shape ?
rounded = output[25]
boxy = output[26]
no_bulge2 = output[27]

all:
    #go to class 6

# %%
#class 10 : featureordisk --> no --> barfeature.yes/no --> arm.yes --> how tights are the arms ?
tight = output[28]
medium = output[29]
loose = output[30]

all:
    #go to class 11

# %%
#class 11: featureordisk --> no --> barfeature.yes/no --> arm.yes --> all arms sizes --> how many arms ?
one_arm = output[31]
two_arms = output[32]
three_arms = output[33]
four_arms = output[34]
more_than_four_arms = output[35]
cant_tell_arms = output[36]

all:
    #go to class 5

# %%
#DEUXIEME CHEMIN
#class 7 : Smooth - how rounded is it ?
completely_round = output[15]
in_beetween = output[16]
cigar_shaped = output[17]

all:
    #go to class 6
