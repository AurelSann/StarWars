# %% [markdown]
# # Exploration

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import set_config; set_config(display='diagram')
from PIL import Image

# %%
Img104648 = Image.open('../raw_data/images_test_rev1/104648.jpg')
Img104648
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=424x424 at 0x1242CC670>

# %%
Img104648array = np.array(Img104648)
Img104648array
# Out:
# array([[[ 9,  9,  9],
#         [ 7,  7,  7],
#         [ 4,  4,  4],
#         ...,
#         [ 6,  4,  5],
#         [ 5,  3,  4],
#         [ 4,  2,  3]],
#
#        [[ 7,  7,  7],
#         [ 5,  5,  5],
#         [ 3,  3,  3],
#         ...,
#         [ 7,  5,  6],
#         [ 6,  4,  5],
#         [ 6,  4,  5]],
#
#        [[ 5,  5,  5],
#         [ 4,  4,  4],
#         [ 3,  3,  3],
#         ...,
#         [ 8,  6,  7],
#         [ 7,  5,  6],
#         [ 7,  5,  6]],
#
#        ...,
#
#        [[ 3,  2,  0],
#         [ 6,  5,  1],
#         [ 8,  7,  5],
#         ...,
#         [ 2,  1,  0],
#         [ 3,  2,  0],
#         [ 9,  8,  6]],
#
#        [[13, 12,  8],
#         [17, 16, 12],
#         [19, 18, 16],
#         ...,
#         [ 6,  5,  3],
#         [ 6,  5,  3],
#         [11, 10,  8]],
#
#        [[25, 24, 20],
#         [28, 27, 23],
#         [30, 29, 27],
#         ...,
#         [ 6,  5,  3],
#         [ 4,  3,  1],
#         [ 6,  5,  3]]], dtype=uint8)

# %%
Img104648array.shape
# Out:
# (424, 424, 3)

# %%
Arrayimage = (np.array(Image.open('../raw_data/images_test_rev1/107120.jpg'))).shape
Arrayimage
# Out:
# (424, 424, 3)

# %%
df = pd.read_csv('../raw_data/central_pixel_benchmark.csv')
df.head()
# Out:
#    GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0    100018  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
# 1    100037  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
# 2    100042  0.408863  0.550817  0.040320  0.085001  0.465816  0.117082
# 3    100052  0.322002  0.657280  0.020718  0.136922  0.520358  0.121784
# 4    100056  0.468481  0.506185  0.025334  0.099844  0.406341  0.095167
#
#    Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 0  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
# 1  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
# 2  0.348734  0.225783  0.240033  ...  0.054510   0.068422   0.087200
# 3  0.398573  0.310370  0.209988  ...  0.058241   0.128488   0.123550
# 4  0.311174  0.185080  0.221262  ...  0.023420   0.082314   0.071253
#
#    Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  Class11.6
# 0   0.031512   0.012281   0.079964   0.014346   0.006369   0.006649          0
# 1   0.031512   0.012281   0.079964   0.014346   0.006369   0.006649          0
# 2   0.070161   0.028580   0.094907   0.017221   0.007030   0.004902          0
# 3   0.058332   0.021707   0.140455   0.028082   0.011659   0.008495          0
# 4   0.031512   0.012281   0.079964   0.014346   0.006369   0.006649          0
#
# [5 rows x 38 columns]

# %% [markdown]
# # Final tree

# %%
output = df.iloc[4,:]
output[1]
# Out:
# 0.468481225

# %%
output
# Out:
# GalaxyID     100056.000000
# Class1.1          0.468481
# Class1.2          0.506185
# Class1.3          0.025334
# Class2.1          0.099844
# Class2.2          0.406341
# Class3.1          0.095167
# Class3.2          0.311174
# Class4.1          0.185080
# Class4.2          0.221262
# Class5.1          0.019015
# Class5.2          0.157050
# Class5.3          0.194386
# Class5.4          0.035891
# Class6.1          0.214295
# Class6.2          0.785705
# Class7.1          0.195927
# Class7.2          0.221751
# Class7.3          0.050803
# Class8.1          0.038988
# Class8.2          0.014479
# Class8.3          0.027519
# Class8.4          0.023837
# Class8.5          0.063031
# Class8.6          0.043247
# Class8.7          0.003193
# Class9.1          0.066032
# Class9.2          0.010392
# Class9.3          0.023420
# Class10.1         0.082314
# Class10.2         0.071253
# Class10.3         0.031512
# Class11.1         0.012281
# Class11.2         0.079964
# Class11.3         0.014346
# Class11.4         0.006369
# Class11.5         0.006649
# Class11.6         0.000000
# Name: 4, dtype: float64

# %%
df['Class1.3'][1]
# Out:
# 0.025333873

# %%
decision_answer = []

# %%
def cat1():
#cat1 : what does it look like ?
    
    smooth = df['Class1.1'][14]
    feature_or_disk = df['Class1.2'][14]
    star = df['Class1.3'][14]

    if smooth > feature_or_disk:
            #go to cat 7
        decision_answer.append('smooth')
        cat7()
                
    elif star > smooth or star > feature_or_disk:
            #STOP --> étoile
            print('output : étoile')  
                
    else:
    #feature_or_disk > all:
            #go to class 2
        decision_answer.append('feature_or_disk')
        cat2() 
                  
    return decision_answer

cat1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0f6d67aab2b5> in <module>
#      23     return decision_answer
#      24
# ---> 25 cat1()
#
# <ipython-input-12-0f6d67aab2b5> in cat1()
#      19             #go to class 2
#      20         decision_answer.append('feature_or_disk')
# ---> 21         cat2()
#      22
#      23     return decision_answer
#
# NameError: name 'cat2' is not defined

# %%
def cat2():
#cat2 : featureordisk --> could this be a disk view edge-on ?
    
    featureordisk_yes = df['Class2.1'][14] 
    featureordisk_no = df['Class2.2'][14]

    if featureordisk_yes > featureordisk_no:
        #go to cat 9
        decision_answer.append('featureordisk_yes')
        cat9()
        
    else:
        #featureordisk_no > featureordisk_yes
        decision_answer.append('featureordisk_no')
        #go to cat 3
        cat3()
        
    return decision_answer

cat2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-82586569e08c> in <module>
#      18     return decision_answer
#      19
# ---> 20 cat2()
#
# <ipython-input-13-82586569e08c> in cat2()
#      14         decision_answer.append('featureordisk_no')
#      15         #go to cat 3
# ---> 16         cat3()
#      17
#      18     return decision_answer
#
# NameError: name 'cat3' is not defined

# %%
def cat3():
#cat 3 : featureordisk --> featureordisk.no --> is there a sign of bar feature ?
    
    barfeature_yes = df['Class3.1'][14] 
    barfeature_no = df['Class3.2'][14] 

    #all : go to cat 4
    
    if barfeature_yes > barfeature_no:
        decision_answer.append('barfeature_yes')
        cat4()
        
    else:
        #barfeature_no > barfeature_yes
        decision_answer.append('barfeature_no')
        cat4()
    
    return decision_answer

cat3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7f0e1f83f462> in <module>
#      18     return decision_answer
#      19
# ---> 20 cat3()
#
# <ipython-input-14-7f0e1f83f462> in cat3()
#      14         #barfeature_no > barfeature_yes
#      15         decision_answer.append('barfeature_no')
# ---> 16         cat4()
#      17
#      18     return decision_answer
#
# NameError: name 'cat4' is not defined

# %%
def cat4():
#cat4 : featureordisk --> no --> barfeature.yes/no --> spiral arm pattern ?

    arm_yes = df['Class4.1'][14] 
    arm_no = df['Class4.2'][14]

    if arm_yes > arm_no:
        #go to cat10
        decision_answer.append('arm_yes')
        cat10()

    else:
        #arm_yes > arm_no
        decision_answer.append('arm_no')
        #go to cat5
        cat5()
    
    return decision_answer       

cat4()

# %%
def cat5():
#cat5 : prominence of central buldge ?
#featureordisk --> no --> barfeature.yes/no --> arm.no
#featureordisk --> no --> barfeature.yes/no --> arm.yes --> all arms sizes --> all number of arms

    no_bulge = df['Class5.1'][14] 
    noticeable_bulge = df['Class5.2'][14] 
    obvious_bulge = df['Class5.3'][14]
    dominant_bulge = df['Class5.4'][14] 

#all: go to cat 6

    if no_bulge > noticeable_bulge and no_bulge > obvious_bulge and no_bulge > dominant_bulge:
        decision_answer.append('no_bulge')
        cat6()
        
    elif noticeable_bulge > no_bulge and noticeable_bulge > obvious_bulge and noticeable_bulge > dominant_bulge:
        decision_answer.append('noticeable_bulge')
        cat6()
        
    elif obvious_bulge > no_bulge and obvious_bulge > noticeable_bulge and obvious_bulge > dominant_bulge:
        decision_answer.append('obvious_bulge')
        cat6()
        
    else:
        #dominant_bulge > all
        decision_answer.append('dominant_bulge')
        cat6()

    
    return decision_answer  
cat5()

# %%
def cat6():
#cat6 - is there anything odd ?
#featureordisk --> no --> barfeature.yes/no --> arm.no --> all
#Smooth --> class 7 : all
#featureordisk --> featureordisk.yes --> class 9 :all

    odd_yes = df['Class6.1'][14] 
    odd_no = df['Class6.2'][14] 

    if odd_yes > odd_no:
        #go to cat 8
        decision_answer.append('odd_yes')
        cat8()    

    else:
        decision_answer.append('odd_no')
        print('output : stop there') 
        #stop --> what is it then ?

    return decision_answer
cat6()

# %%
def cat8():
    #cat8 : featureordisk --> no --> barfeature.yes/no --> arm.no --> all --> odd.yes --> ring, 
    #disturber or irregular ?

    ring = df['Class8.1'][14]
    lens_or_arc = df['Class8.2'][14]
    disturbed = df['Class8.3'][14]
    irregular = df['Class8.4'][14]
    other = df['Class8.5'][14]
    merger = df['Class8.6'][14]
    dust_lane = df['Class8.7'][14]

    #all: stop

    if ring > lens_or_arc and ring > disturbed and ring > irregular and ring > other and ring > merger and ring > dust_lane:
        decision_answer.append('ring')
        #stop
    
    elif lens_or_arc > ring and lens_or_arc > disturbed and lens_or_arc > irregular and lens_or_arc > other and lens_or_arc > merger and lens_or_arc > dust_lane:
        decision_answer.append('lens_or_arc')
        #stop
    
    elif disturbed > lens_or_arc and disturbed > ring and disturbed > irregular and disturbed > other and disturbed > merger and disturbed > dust_lane:
        decision_answer.append('disturbed')
        #stop

    elif irregular > lens_or_arc and irregular > disturbed and irregular > ring and irregular > other and irregular > merger and irregular > dust_lane:
        decision_answer.append('irregular')
        #stop
        
    elif other > lens_or_arc and other > disturbed and other > irregular and other > ring and other > merger and other > dust_lane:
        decision_answer.append('other')
        #stop
        
    elif merger > lens_or_arc and merger > disturbed and merger > irregular and merger > other and merger > ring and merger > dust_lane:
        decision_answer.append('merger')
        #stop
    
    else:
        #dust_lane > all
        decision_answer.append('dust_lane')
        #stop
    return decision_answer


cat8()

# %%
def cat9():
    #cat9 : featureordisk --> featureordisk.yes --> if there a bulge, if yes what shape ?
    
    rounded = df['Class9.1'][14]
    boxy = df['Class9.2'][14]
    no_bulge2 = df['Class9.3'][14]

# all: go to cat6

    if rounded > boxy and rounded > no_bulge2:
        decision_answer.append('rounded')
        cat6()

    elif boxy > rounded and boxy > no_bulge2:
        decision_answer.append('boxy')
        cat6()
    
    else:
        #no_bulge2 > all
        decision_answer.append('no_bulge2')
        cat6()

    return decision_answer

cat9()

# %%
def cat10():
    #cat10 : featureordisk --> no --> barfeature.yes/no --> arm.yes --> how tights are the arms ?
    tight = df['Class10.1'][14]
    medium = df['Class10.2'][14]
    loose = df['Class10.3'][14]

#all: go to cat 11

    if tight > medium and tight > loose:
        decision_answer.append('tight')
        #cat11()

    elif medium > tight and medium > loose:
        decision_answer.append('medium')
        #cat11()
        
    else:
        #loose > all
        decision_answer.append('loose')       
        #cat11()
        
    return decision_answer

cat10()

# %%
def cat11():
#cat 11: featureordisk --> no --> barfeature.yes/no --> arm.yes --> all arms sizes --> how many arms ?
    one_arm = df['Class11.1'][14]
    two_arms = df['Class11.2'][14]
    three_arms = df['Class11.3'][14]
    four_arms = df['Class11.4'][14]
    more_than_four_arms = df['Class11.4'][14]
    cant_tell_arms = df['Class11.5'][14]

#all: go to cat5

    if one_arm > two_arms and one_arm > three_arms and one_arm > four_arms and one_arm > more_than_four_arms and one_arm > cant_tell_arms:
        decision_answer.append('one_arm')
        cat5()

    elif two_arms > one_arm and two_arms > three_arms and two_arms > four_arms and two_arms > more_than_four_arms and two_arms > cant_tell_arms:
        decision_answer.append('two_arms')
        cat5()
        
    elif three_arms > one_arm and three_arms > two_arms and three_arms > four_arms and three_arms > more_than_four_arms and three_arms > cant_tell_arms:
        decision_answer.append('three_arms')
        cat5()  
        
    elif four_arms > one_arm and four_arms > three_arms and four_arms > two_arms and four_arms > more_than_four_arms and four_arms > cant_tell_arms:
        decision_answer.append('four_arms')
        cat5()
        
    elif more_than_four_arms > one_arm and more_than_four_arms > three_arms and more_than_four_arms > four_arms and more_than_four_arms > two_arms and more_than_four_arms > cant_tell_arms:
        decision_answer.append('more_than_four_arms')
        cat5()
    
    else:
        #cant_tell_arms > all
        decision_answer.append('cant_tell_arms')
        cat5()
        
        
    return decision_answer

cat11()

# %%
#DEUXIEME CHEMIN

def cat7():
    #cat7 : Smooth - how rounded is it ?
    completely_round = df['Class7.1'][14]
    in_beetween = df['Class7.2'][14]
    cigar_shaped = df['Class7.3'][14]

#all: go to cat6
    if completely_round > in_beetween and completely_round > cigar_shaped:
        decision_answer.append('completely_round')
        cat6()

    elif in_beetween > completely_round and in_beetween > cigar_shaped:
        decision_answer.append('in_beetween')
        cat6()
    
    else:
        #cigar_shaped > all
        decision_answer.append('cigar_shaped')
        cat6()

    return decision_answer

cat7()
